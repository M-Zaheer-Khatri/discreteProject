# %%
import networkx as nx
import matplotlib.pyplot as plt
g=nx.read_edgelist('RE.txt',create_using=nx.Graph())
print(nx.info(g))
nx.draw(g)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 15
# Number of edges: 14
# Average degree:   1.8667
